# %%
 # !nvidia-smi
# Out:
# Tue Oct 18 16:18:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   28C    P0    45W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/HDC
# Out:
# /content/drive/MyDrive/HDC

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 548 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 163 kB 84.5 MB/s
# ...

# %%
# ! python train.py --data_dir /content/drive/MyDrive/data
# Out:
# Call arguments:
# Namespace(batch_size=128, data_dir='/content/drive/MyDrive/data', no_cuda=False)
# Epoch 0/99
# ----------
# 100% 188/188 [23:51<00:00,  7.61s/it]
# train Loss: 1.2201 Acc: 0.7328
# 100% 32/32 [04:53<00:00,  9.16s/it]
# val Loss: 1.2788 Acc: 0.6643
#
# Epoch 1/99
# ----------
# 100% 188/188 [01:10<00:00,  2.67it/s]
# train Loss: 1.1147 Acc: 0.8552
# 100% 32/32 [00:15<00:00,  2.09it/s]
# val Loss: 1.3007 Acc: 0.6512
#
# Epoch 2/99
# ----------
# 100% 188/188 [01:10<00:00,  2.67it/s]
# train Loss: 1.0649 Acc: 0.9122
# 100% 32/32 [00:15<00:00,  2.11it/s]
# val Loss: 1.3061 Acc: 0.6315
#
# Epoch 3/99
# ----------
# 100% 188/188 [01:10<00:00,  2.66it/s]
# train Loss: 1.0387 Acc: 0.9410
# 100% 32/32 [00:15<00:00,  2.09it/s]
# val Loss: 1.1724 Acc: 0.7885
#
# Epoch 4/99
# ----------
# 100% 188/188 [01:10<00:00,  2.67it/s]
# train Loss: 1.0264 Acc: 0.9553
# 100% 32/32 [00:15<00:00,  2.06it/s]
# val Loss: 1.0839 Acc: 0.8890
#
# Epoch 5/99
# ----------
# ...

# %%
# !python test.py --data_dir /content/drive/MyDrive/data
# Out:
# Call arguments:
# Namespace(batch_size=64, data_dir='/content/drive/MyDrive/data', no_cuda=False)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:709: UserWarning: 'torch.load' received a zip file that looks like a TorchScript archive dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to silence this warning)
#   " silence this warning)", UserWarning)
# 100% 12/12 [00:29<00:00,  2.42s/it]
# Figure(1000x1000)
# Test Loss: 0.0558
# Test Accuracy of level0: 99% (173/174)
# Test Accuracy of level1: 64% (113/175)
# Test Accuracy of level2: 83% (148/177)
# Test Accuracy of level3: 97% (173/178)
# Test Accuracy of 86% (607/704)
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       185
#            1       0.90      0.64      0.75       185
#            2       0.69      0.83      0.75       185
#            3       0.89      0.97      0.93       185
#
#     accuracy                           0.86       740
# ...
